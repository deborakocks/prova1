# %%
x = input ("digite um número: ")
y = input ("digite outro número: ")
z = input ("digite um terceiro número: ")

soma = int(x) + int(y) + int(z)
print (soma)
media = int

if int(x) + int(y)/2 > int(x) + int(z)/2 and int(y) + int (z)/2:
    print (f"a média de x e y é maior") 
else: 
    int(y) + int(z)/2 > int(x) + int(y)/2 and int(x) + int (z)/2
    print (f"a média de y e z é maior")
# Out:
# digite um número:  3
# digite outro número:  2
# digite um terceiro número:  3
# 8
# a média de y e z é maior
